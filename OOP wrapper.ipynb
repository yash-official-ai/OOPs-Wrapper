# %%
class Person:
    def __init__(self,name,age):
        self.name = name
        self.age = age

    def display(self):
        print("nPerson Details:")
        print("Name:", self.name)
        print("Age:", self.age)

class Employee(Person):
    def __init__(self,name,age,employee_id,salay):
        super().__init__(name,age)

        self.__employee_id = employee_id
        self.__salary = salary

    def get_employee_id(self):
        return self.__employee_id 

    def get_salary(self):
        return self.__salary 

    def set_employee_id(self, employee_id):
        self.__employee_id = employee_id

    def set_salary(self, salary):
        self.__salary = salary

    def display(self):
        print("\nEmployee Details:")
        print("Name:", self.name)
        print("Age:", self.age)
        print("Employee ID:", self.__employee_id)
        print("Salary: $", self.__salary)

    def __del__(self):
        print("\nEmployee object destroyed.")

class Manager(Employee):

    def __init__(self,name,age,employee_id,salary,department):

        super().__init__(name,age,salary,employee_id)
        
        self.department = department

    def display(self):
        print("\nManager Details:")
        print("Name:", self.name)
        print("Age:", self.age)
        print("Employee ID:", self.employee_id())
        print("Salary: $", self.get_salary())
        print("Department:", self.department)



person = None
employee = None
manager = None


while True:

    print("\n--- Python OOP project: Employee Management System ---")

    print("\nChoose an operation:")
    print("1. Create a person")
    print("2. Create an employee")
    print("3. Create a Manager")
    print("4. Show Details")
    print("5. Exit")

    choice = int(input("\nEnter Your Choice: "))

    if choice == 1:

        name = input("\nEnter Name: ")
        age = int(input("Enter Age: "))

        person = Person(name, age)

        print("\nperson created with name:",name, "and age:", age)


    elif choice == 2:

        name = input("\nEnter your name: ")
        age = int(input("Enter Age: "))
        emp_id = input("Enter Employee ID: ")
        salary = float(input("Enter Salary: "))

        employee = Employee(name, age, emp_id, salary)

        print("\nEmployee created with name:", name,
             ", age:",age,
             ", ID:", emp_id,
             ", and salary: $", salary)

    elif choice == 3:

        name = input("\nEnter your name: ")
        age = int(input("Enter age: "))
        emp_id = input("Enter Employee ID: ")
        salary = float(input("Enter Salary: "))
        department = input("Enter Department: ")

        manager = Manager(name,age,emp_id,salary,department)

        print("\nManager created with name:", name,
              ", age:", age,
              ", ID:", emp_id,
              ", salary: $", salary,
              ", and department:", department)

    elif choice == 4:

        print("\nChoose details to show:")
        print("1. Person")
        print("2. Employee")
        print("3. Manager")

        detail_choice = int(input("\nEnter your choice: "))

        if detail_choice == 1:
            if person:
                person.display()
            else:
                print("\nNo Person data found.")

        elif detail_choice == 2:
            if employee:
                employee.display()
            else:
                print("\nNo Employee data found.")

        elif detail_choice == 3:
            if manager:
                manager.display()
            else:
                print("\nNo Manager data found.")

        else:
            print("\nInvalid choice.")

    elif choice == 5:

        print("\nExiting the system. All resources have been freed. ")
        print("Goodbye!!")

        break

    else:
        print("\nInvalid choice. Please try again. ")


print("\nChecking Inheritance:")
print("Is Manager subclass of employee?",
       issubclass(Manager,Employee))
# Out:
# Employee object destroyed.
#
# Employee object destroyed.
#
# --- Python OOP project: Employee Management System ---
#
# Choose an operation:
# 1. Create a person
# 2. Create an employee
# 3. Create a Manager
# 4. Show Details
# 5. Exit
# Enter Your Choice:  1
#
# Enter Name:  donald
# Enter Age:  45
# person created with name: donald and age: 45
#
# --- Python OOP project: Employee Management System ---
#
# Choose an operation:
# 1. Create a person
# 2. Create an employee
# 3. Create a Manager
# 4. Show Details
# 5. Exit
# Enter Your Choice:  2
#
# Enter your name:  Akshat
# Enter Age:  30
# Enter Employee ID:  G876
# Enter Salary:  5600
# Employee created with name: Akshat , age: 30 , ID: G876 , and salary: $ 5600.0
#
# --- Python OOP project: Employee Management System ---
#
# Choose an operation:
# 1. Create a person
# 2. Create an employee
# 3. Create a Manager
# 4. Show Details
# 5. Exit
# Enter Your Choice:  3
#
# Enter your name:  yash
# Enter age:  32
# Enter Employee ID:  M978
# Enter Salary:  10000
# Enter Department:  sales
# Manager created with name: yash , age: 32 , ID: M978 , salary: $ 10000.0 , and department: sales
#
# --- Python OOP project: Employee Management System ---
#
# Choose an operation:
# 1. Create a person
# 2. Create an employee
# 3. Create a Manager
# 4. Show Details
# 5. Exit
# Enter Your Choice:  4
# Choose details to show:
# 1. Person
# 2. Employee
# 3. Manager
# Enter your choice:  2
# Employee Details:
# Name: Akshat
# Age: 30
# Employee ID: G876
# Salary: $ 5600.0
#
# --- Python OOP project: Employee Management System ---
#
# Choose an operation:
# 1. Create a person
# 2. Create an employee
# 3. Create a Manager
# 4. Show Details
# 5. Exit
# Enter Your Choice:  5
# Exiting the system. All resources have been freed.
# Goodbye!!
#
# Checking Inheritance:
# Is Manager subclass of employee? True
